# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeep0097-97/sandeep0097-97/blob/main/Copy_of_Day_3__Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYTHON**

# %% [markdown]
# ## 1. Given a string consisting of whitespace and groups of matched parentheses, write a Python program to split it into groups of perfectly matched parentheses without any whitespace.
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your Code here
def test(combined):
    ls = []
    s2 = ""
    for s in combined.replace(' ', ''):
        s2 += s
        if s2.count("(") == s2.count(")"):
            ls.append(s2)
            s2 = ""
    return ls
combined = '( ()) ((()()())) (()) ()'
print("Parentheses string:")
print(combined)
print("Separate parentheses groups of the said string:")
print(test(combined))
combined = '() (( ( )() (   )) ) ( ())'
print("\nParentheses string:")
print(combined)
print("Separate parentheses groups of the said string:")
print(test(combined))
# Out:
# Parentheses string:
# ( ()) ((()()())) (()) ()
# Separate parentheses groups of the said string:
# ['(())', '((()()()))', '(())', '()']
#
# Parentheses string:
# () (( ( )() (   )) ) ( ())
# Separate parentheses groups of the said string:
# ['()', '((()()()))', '(())']

# %% [markdown]
# ## 2. Write a Python program to find the strings in a given list, starting with a given prefix.
#
# ![image.png](data:image/png;base64,...)

# %%
# Write Your Code here
def test(strs, prefix):
     return [s for s in strs if s.startswith(prefix)]
strs =  ['cat', 'car', 'fear', 'center']
prefix = "ca"
print("Original strings:")
print(strs)
print("Starting prefix:", prefix)
print("Strings in the said list starting with a given prefix:")
print(test(strs, prefix))
strs =  ['cat', 'dog', 'shatter', 'donut', 'at', 'todo']
prefix = "do"
print("\nOriginal strings:")
print(strs)
print("Starting prefix:", prefix)
print("Strings in the said list starting with a given prefix:")
print(test(strs, prefix))
# Out:
# Original strings:
# ['cat', 'car', 'fear', 'center']
# Starting prefix: ca
# Strings in the said list starting with a given prefix:
# ['cat', 'car']
#
# Original strings:
# ['cat', 'dog', 'shatter', 'donut', 'at', 'todo']
# Starting prefix: do
# Strings in the said list starting with a given prefix:
# ['dog', 'donut']

# %% [markdown]
# # **SQL**

# %% [markdown]
# ## 3. From the following dataframe, write a SQL query to find all dates' city ID with higher pollution compared to its previous dates (yesterday). Return city ID, date and pollution.
#
# **Create Dataframe : so2_pollution**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Install SQlite & Pandasql
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test3_database')
c = conn.cursor()


# Create table
c.execute('''DROP TABLE IF EXISTS so2_pollution;''')

c.execute('''CREATE TABLE so2_pollution (
[city_id] INTEGER,
[date]  DATE,
[so2_amt] INTEGER );''')



# Insert data into table
c.execute('''INSERT INTO so2_pollution (city_id, date,so2_amt) VALUES ('701', '2015-10-15', '5');''')
c.execute('''INSERT INTO so2_pollution (city_id, date,so2_amt) VALUES ('702', '2015-10-16', '7');''')
c.execute('''INSERT INTO so2_pollution (city_id, date,so2_amt) VALUES ('703', '2015-10-17', '9');''')
c.execute('''INSERT INTO so2_pollution (city_id, date,so2_amt) VALUES ('704', '2018-10-18', '15');''')
c.execute('''INSERT INTO so2_pollution (city_id, date,so2_amt) VALUES ('705', '2015-10-19', '14');''')


conn.commit()

# Get DataFrame
conn = sqlite3.connect('test3_database')
so2_pollution = pd.read_sql_query ('''SELECT * FROM so2_pollution''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 171 kB 9.5 MB/s
# ...
#   Created wheel for db-sqlite3: filename=db_sqlite3-0.0.1-py3-none-any.whl size=1794 sha256=ccd1e189f8d63aa36c64712c4675fce19c80d1dfee8423908bc7ccb197060738
#   Stored in directory: /root/.cache/pip/wheels/02/38/d5/2f54461050571bf5330fee2a37ab1c9b5e7540b0572f1acdab
# ...
#   Created wheel for db: filename=db-0.1.1-py3-none-any.whl size=3895 sha256=404c178b190ec2ead7fe393966858b27478c498c03e64b10037c669b47dfa574
#   Stored in directory: /root/.cache/pip/wheels/8e/97/82/741d2b360507411ec233d0280d7371faa94b03bde834e4a9be
# ...
#   Created wheel for antiorm: filename=antiorm-1.2.1-py3-none-any.whl size=31679 sha256=fc12f26a375b6288e6acf852b619a146bf297b278924cdcf1b79fab4587ceb5c
#   Stored in directory: /root/.cache/pip/wheels/c5/43/70/e9729370cfff40c49d3e3d05377d54b3ecd71f64e62341ea80
# Successfully built db-sqlite3 db antiorm
# ...

# %%
# Write Your Code here
mysql('''SELECT p2.city_id FROM so2_pollution p1, so2_pollution p2
WHERE p2.date = date(p1.date,'+1day')
AND p1.so2_amt < p2.so2_amt''')

# %% [markdown]
# ## 4. From the following dataframe, write a SQL query to find the even or odd values.
# ## Return "Even" for even number and "Odd" for odd number.
#
# **Creating Dataframe: tablefortest**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Expected Output:**
#
# ![image.png](data:image/png;base64,...)

# %%
# Install SQlite & Pandasql
# !pip install db-sqlite3
# !pip install pandasql

# Importing Libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
mysql = lambda q: sqldf(q, globals())


# Connection to DataBase
conn = sqlite3.connect('test3_database')
c = conn.cursor()

# Create table
c.execute('''DROP TABLE IF EXISTS tablefortest;''')

c.execute('''CREATE TABLE tablefortest (
[srno] INTEGER,
[col_val] INTEGER );''')



# Insert data into table
c.execute('''INSERT INTO tablefortest VALUES (1, 56);''')
c.execute('''INSERT INTO tablefortest VALUES (2, 74);''')
c.execute('''INSERT INTO tablefortest VALUES (3, 15);''')
c.execute('''INSERT INTO tablefortest VALUES (4, 51);''')
c.execute('''INSERT INTO tablefortest VALUES (5, 9);''')
c.execute('''INSERT INTO tablefortest VALUES (6, 32);''')



conn.commit()

# Get DataFrame
conn = sqlite3.connect('test3_database')
tablefortest = pd.read_sql_query ('''SELECT * FROM tablefortest''',conn)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Write Your Code here
mysql('''SELECT srno, col_val,
     CASE WHEN col_val%2=0 THEN 'Even'
          WHEN col_val%2=1 THEN 'Odd'
          END AS Even_or_Odd
     FROM tablefortest;''')
# Out:
#    srno  col_val Even_or_Odd
# 0     1       56        Even
# 1     2       74        Even
# 2     3       15         Odd
# 3     4       51         Odd
# 4     5        9         Odd
# 5     6       32        Even

# %% [markdown]
# # **MATH**

# %% [markdown]
# ## 5. Find out the inverse of the 3x3 matrix.
#
# ![image.png](data:image/png;base64,...)
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![WhatsApp Image 2022-06-30 at 9.28.21 AM.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# ## 6. Find all eigenvalues and corresponding eigenvectors for the matrix.
#
# ![image.png](data:image/png;base64,...)
#
# **Solve this on a piece of paper and submit the image.**

# %% [markdown]
# ![WhatsApp Image 2022-06-30 at 9.13.10 AM.jpeg](data:image/jpeg;base64,...)Upload your answer here.

# %% [markdown]
# # **MACHINE LEARNING**

# %% [markdown]
# ## 7. What is multicollinearity, and how do you treat it and when is it not a problem?

# %% [markdown]
# Write your answer here.
#
# Multicollinearity is refers to the high correlation between two or more explanatory variables.
# We can treat by dropping one feature if in a problem features are less.but if we have laeger  number of dataset say 150 to 160 features .Then its better to use ridge or lasso regression .Then we dont have to drop any feature.

# %% [markdown]
# ## 8. VIF(Variation Inflation Factor),Weight of Evidence & Information Value. Why and when to use?

# %% [markdown]
# Write your answer here.
#
#
# Variation inflation factor is  commonly used tool to detect whether multicollinearity exists in a regression model or not. It measures how much the variance (or standard error) of the estimated regression coefficient is inflated due to collinearity.
#
# The weight of evidence tells the predictive power of an independent variable in relation to the dependent variable.
#
# Information Value analysis is a data exploration technique that helps determine which columns in a data set have predictive power or influence on the value of a specified dependent variable.
